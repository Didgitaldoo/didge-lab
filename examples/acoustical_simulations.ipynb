# %%
import numpy as np
import sys
sys.path.append("..")

from didgelab import acoustical_simulation, Geo
import matplotlib.pyplot as plt

geo = Geo([[0,32], [1200,32]])
freqs = np.arange(30, 1000, 1)
impedances = acoustical_simulation(geo, freqs, simulation_backend="tlm_cython")

plt.plot(freqs, impedances)

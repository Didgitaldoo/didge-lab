# %%
import os
import sys
import matplotlib.pyplot as plt
import json

sys.path.append("../../")
from didgelab.analysis import *

def get_latest_folder():
    indir = "../../../evolutions/"
    files = os.listdir(indir)
    files = list(filter(lambda f:os.path.isdir(os.path.join(indir, f)), sorted(files)))
    return os.path.join(indir, files[-1])

indir = get_latest_folder()
#saved_evolutions/evolution_operations.jsonl.gz
#2024-05-16T21-32-01_simulation/"

# %%
infile = os.path.join(indir, "evolution_operations.jsonl.gz")
nodes = build_graph(infile)
deltas = get_deltas(nodes)
plot_success_probs_over_time(deltas)
plt.show()
plot_loss_over_time(nodes)

# %%
i=0
counts = []
while True:
    generation = nodes.get_generation(i)
    if len(generation) == 0:
        break

    operations = []
    for node in generation:
        operations.extend([c.name for c in node.children])
    operations = np.unique(operations, return_counts=True)
    for j in range(len(operations[0])):
        counts.append({
            "generation": i,
            "operation": operations[0][j],
            "count": operations[1][j],
        })
    #counts.append({
    #    "generation": i,
    #    "operation": "total",
    #    "count": np.sum(operations[1]),
    #})

    i+=1

counts = pd.DataFrame(counts)
sns.lineplot(data=counts, x="generation", y="count", hue="operation")
plt.title("Number of operations per generation")
# Out:
# Text(0.5, 1.0, 'Number of operations per generation')

# %%
infile = os.path.join(indir, "latest_population.json")
population = json.load(open(infile))["population"]

reference = '{"impedance": {"0": 1.0, "1": 0.8576649663048393, "2": 0.6066206728881713, "3": 0.8420721962421757, "4": 0.8373902860195547, "5": 0.8084926830620255, "6": 0.7780097302125277, "7": 0.6681873008986587, "8": 0.6864601376736074, "9": 0.8340840526459629, "10": 0.44992931052124463}, "freq": {"0": 91.91400470014798, "1": 184.52432761772133, "2": 276.4383323178693, "3": 368.3523370180173, "4": 440.2663417181653, "5": 572.1803464183132, "6": 644.7906693358866, "7": 736.7046740360346, "8": 827.9223605187572, "9": 921.2290016537559, "10": 999.2166420053966}, "harmonic_series": {"0": 91.91400470014798, "1": 183.82800940029597, "2": 275.74201410044395, "3": 367.65601880059194, "4": 459.5700235007399, "5": 551.4840282008879, "6": 643.3980329010359, "7": 735.3120376011839, "8": 827.2260423013319, "9": 919.1400470014798, "10": 1011.0540517016278}, "diff": {"0": 0.0, "1": -0.6963182174253575, "2": -0.6963182174253575, "3": -0.6963182174253575, "4": 19.303681782574643, "5": -20.6963182174253, "6": -1.392636434850715, "7": -1.392636434850715, "8": -0.6963182174253006, "9": -2.0889546522760156, "10": 11.837409696231248}}'
reference = pd.DataFrame(json.loads(reference))

def visualize_individuals(population, n=None, base_freq=440):

    if n is not None and n<len(population):
        population = population[0:n]

    for i in range(len(population)):
        geo = population[i]["representation"]["geo"]
        geo = Geo(geo)
        freqs = get_log_simulation_frequencies(1, 1000, 5)
        segments = create_segments(geo)
        impedance = compute_impedance(segments, freqs)
        notes = get_notes(freqs, impedance, base_freq=base_freq)
        notes["mult"] = [notes.freq.iloc[0]*i for i in range(1, len(notes)+1)]
        notes["ref"] = [reference.freq[np.argmin(np.abs(reference.freq-f))] for f in notes.freq]
        notes["mult_diff"] = notes.freq - notes.mult
        
        print("*"*50)
        print(f"Individual {i}")
        print("*"*50)
        columns = ['note_name', 'freq', 'ref', 'mult', 'mult_diff']
        print(notes[columns].round(2))
        vis_didge(geo)
        plt.show()
        plt.plot(freqs, impedance)
        plt.title("Impedance spektrum")
        plt.show()
        print(f"Impedance sum: {notes.impedance.sum():.2f}")
        print(f"Volume: {geo.compute_volume()/1000:.2f} cm3")
        print(f"Length: {geo.geo[-1][0]/10:.2f} cm")
        print(f"Bell diameter: {geo.geo[-1][1]/10:.2f} cm")
        print()

visualize_individuals(population, n=10)
# Out:
# **************************************************
# Individual 0
# **************************************************
#   note_name    freq     ref    mult  mult_diff
# 0        E1   83.72   91.91   83.72       0.00
# 1       G#2  203.78  184.52  167.44      36.34
# 2        E3  323.47  368.35  251.16      72.31
# 3       A#4  454.82  440.27  334.88     119.94
# 4        D4  583.06  572.18  418.60     164.46
# 5       F#4  719.91  736.70  502.32     217.59
# 6       G#4  843.84  827.92  586.04     257.80
# 7        B5  969.32  999.22  669.76     299.56
# Impedance sum: 43.97
# Volume: 66.03 cm3
# Length: 132.00 cm
# Bell diameter: 6.36 cm
#
# **************************************************
# Individual 1
# **************************************************
#   note_name    freq     ref    mult  mult_diff
# 0        E1   83.72   91.91   83.72       0.00
# 1       G#2  202.60  184.52  167.44      35.16
# 2        E3  327.23  368.35  251.16      76.07
# 3        A4  452.21  440.27  334.88     117.33
# 4        D4  583.06  572.18  418.60     164.46
# 5       F#4  719.91  736.70  502.32     217.59
# 6       G#4  846.29  827.92  586.04     260.25
# 7        B5  966.53  999.22  669.76     296.77
# Impedance sum: 43.79
# Volume: 66.36 cm3
# Length: 132.00 cm
# Bell diameter: 6.36 cm
#
# **************************************************
# Individual 2
# **************************************************
#   note_name    freq     ref    mult  mult_diff
# 0        E1   84.20   91.91   84.20       0.00
# 1       G#2  203.19  184.52  168.41      34.78
# 2        E3  327.23  368.35  252.61      74.62
# 3       A#4  453.51  440.27  336.82     116.69
# 4        D4  584.75  572.18  421.02     163.72
# 5       F#4  719.91  736.70  505.23     214.68
# 6       G#4  846.29  827.92  589.43     256.85
# 7        B5  963.74  999.22  673.64     290.10
# Impedance sum: 41.19
# Volume: 66.55 cm3
# Length: 132.00 cm
# Bell diameter: 6.66 cm
#
# **************************************************
# Individual 3
# **************************************************
#   note_name    freq     ref    mult  mult_diff
# 0        G1   95.62   91.91   95.62       0.00
# 1        A3  226.10  184.52  191.23      34.87
# 2       F#3  366.25  368.35  286.85      79.40
# 3        C4  512.00  572.18  382.46     129.54
# 4        E4  652.58  644.79  478.08     174.50
# 5        G4  803.41  827.92  573.69     229.72
# 6       A#5  949.92  921.23  669.31     280.62
# Impedance sum: 40.52
# Volume: 59.22 cm3
# Length: 117.44 cm
# Bell diameter: 6.36 cm
#
# **************************************************
# Individual 4
# **************************************************
#   note_name    freq     ref    mult  mult_diff
# 0        E1   83.96   91.91   83.96       0.00
# 1       G#2  203.78  184.52  167.92      35.85
# 2        E3  327.23  368.35  251.89      75.34
# 3       A#4  453.51  440.27  335.85     117.66
# 4        D4  586.44  572.18  419.81     166.63
# 5       F#4  719.91  736.70  503.77     216.13
# 6       G#4  843.84  827.92  587.73     256.11
# 7        B5  963.74  999.22  671.70     292.04
# Impedance sum: 41.13
# Volume: 66.75 cm3
# Length: 132.00 cm
# Bell diameter: 6.66 cm
#
# **************************************************
# Individual 5
# **************************************************
#   note_name    freq     ref    mult  mult_diff
# 0       F#1   94.79   91.91   94.79       0.00
# 1       A#3  226.76  184.52  189.58      37.18
# 2       F#3  366.25  368.35  284.37      81.87
# 3        C4  512.00  572.18  379.16     132.84
# 4        E4  650.69  644.79  473.95     176.74
# 5        G4  801.10  827.92  568.74     232.36
# 6       A#5  949.92  921.23  663.53     286.39
# Impedance sum: 41.30
# Volume: 58.46 cm3
# Length: 117.44 cm
# Bell diameter: 6.25 cm
#
# **************************************************
# Individual 6
# **************************************************
#   note_name    freq     ref    mult  mult_diff
# 0        F1   86.17   91.91   86.17       0.00
# 1        A3  216.52  184.52  172.35      44.17
# 2        E3  336.82  368.35  258.52      78.30
# 3        B4  486.06  440.27  344.69     141.37
# 4       D#4  608.87  644.79  430.87     178.01
# 5       F#4  751.78  736.70  517.04     234.74
# 6        A5  881.20  921.23  603.21     277.99
# Impedance sum: 40.98
# Volume: 64.35 cm3
# Length: 126.01 cm
# Bell diameter: 6.45 cm
#
# **************************************************
# Individual 7
# **************************************************
#   note_name    freq     ref    mult  mult_diff
# 0        A2  111.75   91.91  111.75       0.00
# 1        C3  265.79  276.44  223.51      42.29
# 2        A4  430.54  440.27  335.26      95.28
# 3        D4  594.97  572.18  447.01     147.96
# 4        G4  769.35  736.70  558.76     210.59
# 5       A#5  936.30  921.23  670.52     265.79
# Impedance sum: 35.10
# Volume: 49.92 cm3
# Length: 100.00 cm
# Bell diameter: 6.25 cm
#
# **************************************************
# Individual 8
# **************************************************
#   note_name    freq     ref    mult  mult_diff
# 0       F#1   95.06   91.91   95.06       0.00
# 1        A3  226.10  184.52  190.13      35.97
# 2       F#3  367.30  368.35  285.19      82.11
# 3        B4  507.58  572.18  380.26     127.33
# 4        E4  656.36  644.79  475.32     181.03
# 5        G4  798.79  827.92  570.39     228.40
# 6       A#5  949.92  921.23  665.45     284.47
# Impedance sum: 41.36
# Volume: 58.63 cm3
# Length: 117.44 cm
# Bell diameter: 6.25 cm
#
# **************************************************
# Individual 9
# **************************************************
#   note_name    freq     ref    mult  mult_diff
# 0       F#1   94.24   91.91   94.24       0.00
# 1        A3  226.10  184.52  188.49      37.61
# 2       F#3  362.04  368.35  282.73      79.31
# 3        B4  500.31  440.27  376.98     123.33
# 4        E4  646.95  644.79  471.22     175.72
# 5        G4  796.48  827.92  565.47     231.02
# 6       A#5  936.30  921.23  659.71     276.59
# Impedance sum: 40.14
# Volume: 60.03 cm3
# Length: 118.96 cm
# Bell diameter: 6.46 cm

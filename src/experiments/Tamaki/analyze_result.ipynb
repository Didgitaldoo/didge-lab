# %%
import os
import sys
import matplotlib.pyplot as plt
import json

sys.path.append("../../")
from didgelab.analysis import *

#saved_evolutions/evolution_operations.jsonl.gz
indir = "../../../saved_evolutions/2024-04-20T11-50-54_evolve_tamaki3/"

# %%
infile = os.path.join(indir, "evolution_operations.jsonl.gz")
nodes = build_graph(infile)
deltas = get_deltas(nodes)
plot_success_probs_over_time(deltas)
plt.show()
plot_loss_over_time(nodes)

# %%
infile = "../../../saved_evolutions/test/tamaki_pop.json"
population = json.load(open(infile))["population"]

reference = '{"impedance": {"0": 1.0, "1": 0.8576649663048393, "2": 0.6066206728881713, "3": 0.8420721962421757, "4": 0.8373902860195547, "5": 0.8084926830620255, "6": 0.7780097302125277, "7": 0.6681873008986587, "8": 0.6864601376736074, "9": 0.8340840526459629, "10": 0.44992931052124463}, "freq": {"0": 91.91400470014798, "1": 184.52432761772133, "2": 276.4383323178693, "3": 368.3523370180173, "4": 440.2663417181653, "5": 572.1803464183132, "6": 644.7906693358866, "7": 736.7046740360346, "8": 827.9223605187572, "9": 921.2290016537559, "10": 999.2166420053966}, "harmonic_series": {"0": 91.91400470014798, "1": 183.82800940029597, "2": 275.74201410044395, "3": 367.65601880059194, "4": 459.5700235007399, "5": 551.4840282008879, "6": 643.3980329010359, "7": 735.3120376011839, "8": 827.2260423013319, "9": 919.1400470014798, "10": 1011.0540517016278}, "diff": {"0": 0.0, "1": -0.6963182174253575, "2": -0.6963182174253575, "3": -0.6963182174253575, "4": 19.303681782574643, "5": -20.6963182174253, "6": -1.392636434850715, "7": -1.392636434850715, "8": -0.6963182174253006, "9": -2.0889546522760156, "10": 11.837409696231248}}'
reference = pd.DataFrame(json.loads(reference))

def visualize_individuals(population, n=None, base_freq=440):

    if n is not None and n<len(population):
        population = population[0:n]

    for i in range(len(population)):
        geo = population[i]["representation"]["geo"]
        geo = Geo(geo)
        freqs = get_log_simulation_frequencies(1, 1000, 5)
        segments = create_segments(geo)
        impedance = compute_impedance(segments, freqs)
        notes = get_notes(freqs, impedance, base_freq=base_freq)
        notes["mult"] = [notes.freq.iloc[0]*i for i in range(1, len(notes)+1)]
        notes["ref"] = [reference.freq[np.argmin(np.abs(reference.freq-f))] for f in notes.freq]
        notes["mult_diff"] = notes.freq - notes.mult
        
        print("*"*50)
        print(f"Individual {i}")
        print("*"*50)
        columns = ['note_name', 'freq', 'ref', 'mult', 'mult_diff']
        print(notes[columns].round(2))
        vis_didge(geo)
        plt.show()
        plt.plot(freqs, impedance)
        plt.title("Impedance spektrum")
        plt.show()
        print(f"Impedance sum: {notes.impedance.sum():.2f}")
        print(f"Volume: {geo.compute_volume()/1000:.2f} cm3")
        print(f"Length: {geo.geo[-1][0]/10:.2f} cm")
        print(f"Bell diameter: {geo.geo[-1][1]/10:.2f} cm")
        print()

visualize_individuals(population, n=10)
# Out:
# **************************************************
# Individual 0
# **************************************************
#   note_name    freq     ref    mult  mult_diff
# 0       F#1   91.30   91.91   91.30       0.00
# 1        E2  165.52  184.52  182.59     -17.08
# 2       C#3  278.36  276.44  273.89       4.47
# 3        G3  393.67  368.35  365.19      28.48
# 4        B4  494.56  440.27  456.49      38.07
# 5       D#4  614.17  644.79  547.78      66.39
# 6       F#4  734.61  736.70  639.08      95.53
# 7        A5  866.07  827.92  730.38     135.69
# Impedance sum: 56.83
# Volume: 80.32 cm3
# Length: 152.16 cm
# Bell diameter: 7.91 cm
#
# **************************************************
# Individual 1
# **************************************************
#   note_name    freq     ref    mult  mult_diff
# 0       F#1   91.03   91.91   91.03       0.00
# 1        E2  164.56  184.52  182.07     -17.50
# 2       C#3  280.79  276.44  273.10       7.69
# 3        G3  395.95  368.35  364.14      31.81
# 4        B4  495.99  440.27  455.17      40.82
# 5       D#4  610.64  644.79  546.20      64.43
# 6       F#4  738.86  736.70  637.24     101.63
# 7        A5  856.12  827.92  728.27     127.85
# Impedance sum: 58.49
# Volume: 77.06 cm3
# Length: 152.00 cm
# Bell diameter: 7.91 cm
#
# **************************************************
# Individual 2
# **************************************************
#   note_name    freq     ref    mult  mult_diff
# 0       F#1   91.30   91.91   91.30       0.00
# 1        E2  166.00  184.52  182.59     -16.60
# 2       C#3  278.36  276.44  273.89       4.47
# 3        G3  390.27  368.35  365.19      25.08
# 4        B4  501.75  440.27  456.49      45.27
# 5       D#4  610.64  644.79  547.78      62.85
# 6       F#4  736.73  736.70  639.08      97.65
# 7        A5  868.57  827.92  730.38     138.19
# Impedance sum: 55.75
# Volume: 79.78 cm3
# Length: 152.19 cm
# Bell diameter: 7.99 cm
#
# **************************************************
# Individual 3
# **************************************************
#   note_name    freq     ref    mult  mult_diff
# 0       F#1   91.03   91.91   91.03       0.00
# 1        E2  167.44  184.52  182.07     -14.63
# 2       C#3  277.56  276.44  273.10       4.46
# 3        G3  392.53  368.35  364.14      28.40
# 4        B4  501.75  440.27  455.17      46.58
# 5       D#4  607.12  572.18  546.20      60.91
# 6       F#4  741.00  736.70  637.24     103.76
# 7        A5  863.57  827.92  728.27     135.30
# Impedance sum: 55.50
# Volume: 79.72 cm3
# Length: 152.00 cm
# Bell diameter: 7.98 cm
#
# **************************************************
# Individual 4
# **************************************************
#   note_name    freq     ref    mult  mult_diff
# 0       F#1   91.30   91.91   91.30       0.00
# 1        E2  164.09  184.52  182.59     -18.51
# 2       C#3  279.17  276.44  273.89       5.28
# 3        G3  391.40  368.35  365.19      26.21
# 4        B4  494.56  440.27  456.49      38.07
# 5       D#4  614.17  644.79  547.78      66.39
# 6       F#4  732.49  736.70  639.08      93.41
# 7        A5  858.59  827.92  730.38     128.22
# Impedance sum: 57.48
# Volume: 79.09 cm3
# Length: 152.61 cm
# Bell diameter: 7.94 cm
#
# **************************************************
# Individual 5
# **************************************************
#   note_name    freq     ref    mult  mult_diff
# 0       F#1   91.30   91.91   91.30       0.00
# 1        E2  165.52  184.52  182.59     -17.08
# 2       C#3  279.98  276.44  273.89       6.09
# 3        G3  392.53  368.35  365.19      27.34
# 4        B4  497.42  440.27  456.49      40.94
# 5       D#4  614.17  644.79  547.78      66.39
# 6       F#4  734.61  736.70  639.08      95.53
# 7        A5  868.57  827.92  730.38     138.19
# Impedance sum: 56.20
# Volume: 78.43 cm3
# Length: 152.00 cm
# Bell diameter: 8.00 cm
#
# **************************************************
# Individual 6
# **************************************************
#   note_name    freq     ref    mult  mult_diff
# 0       F#1   91.56   91.91   91.56       0.00
# 1        E2  166.00  184.52  183.12     -17.13
# 2       C#3  277.56  276.44  274.68       2.88
# 3        G3  393.67  368.35  366.25      27.42
# 4        B4  497.42  440.27  457.81      39.62
# 5       D#4  617.73  644.79  549.37      68.36
# 6       F#4  732.49  736.70  640.93      91.56
# 7        A5  873.60  827.92  732.49     141.11
# Impedance sum: 56.08
# Volume: 78.93 cm3
# Length: 152.00 cm
# Bell diameter: 8.00 cm
#
# **************************************************
# Individual 7
# **************************************************
#   note_name    freq     ref    mult  mult_diff
# 0       F#1   91.03   91.91   91.03       0.00
# 1        E2  166.96  184.52  182.07     -15.11
# 2       C#3  276.76  276.44  273.10       3.66
# 3        G3  395.95  368.35  364.14      31.81
# 4        B4  498.86  440.27  455.17      43.69
# 5       D#4  614.17  644.79  546.20      67.97
# 6       F#4  732.49  736.70  637.24      95.25
# 7        A5  866.07  827.92  728.27     137.79
# Impedance sum: 56.38
# Volume: 79.50 cm3
# Length: 152.00 cm
# Bell diameter: 8.00 cm
#
# **************************************************
# Individual 8
# **************************************************
#   note_name    freq     ref    mult  mult_diff
# 0       F#1   91.03   91.91   91.03       0.00
# 1        E2  166.00  184.52  182.07     -16.07
# 2       C#3  275.96  276.44  273.10       2.86
# 3        G3  392.53  368.35  364.14      28.40
# 4        B4  500.31  440.27  455.17      45.14
# 5       D#4  608.87  644.79  546.20      62.67
# 6       F#4  732.49  736.70  637.24      95.25
# 7        A5  863.57  827.92  728.27     135.30
# Impedance sum: 56.04
# Volume: 79.61 cm3
# Length: 152.46 cm
# Bell diameter: 7.99 cm
#
# **************************************************
# Individual 9
# **************************************************
#   note_name    freq     ref    mult  mult_diff
# 0       F#1   91.03   91.91   91.03       0.00
# 1        E2  164.56  184.52  182.07     -17.50
# 2       C#3  280.79  276.44  273.10       7.69
# 3        G3  394.81  368.35  364.14      30.67
# 4        B4  497.42  440.27  455.17      42.25
# 5       D#4  608.87  644.79  546.20      62.67
# 6       F#4  747.45  736.70  637.24     110.21
# 7       G#4  838.98  827.92  728.27     110.71
# Impedance sum: 56.08
# Volume: 79.50 cm3
# Length: 152.00 cm
# Bell diameter: 7.91 cm

# %%
from dolfinx.io import XDMFFile
from dolfinx.mesh import meshtags_from_entities
from dolfinx.cpp.mesh import cell_entity_type
from dolfinx.io import distribute_entity_data
from dolfinx.graph import adjacencylist
from dolfinx.mesh import create_mesh
from dolfinx.cpp.mesh import to_type
from dolfinx.cpp.io import perm_gmsh
import numpy
from dolfinx.io import gmshio
from mpi4py import MPI
from dolfinx.io.gmshio import model_to_mesh
import numpy as np
import gmsh
import warnings

warnings.filterwarnings("ignore")
gmsh.initialize()

# %%
gmsh.model.add("DFG 3D")
L, B, H, r = 2.5, 0.41, 0.41, 0.05
channel = gmsh.model.occ.addBox(0, 0, 0, L, B, H)
cylinder = gmsh.model.occ.addCylinder(0.5, 0, 0.2, 0, B, 0, r)

# %%
import math 

def main():
    gmsh.initialize()
    
    # alias to facilitate code writing
    factory = gmsh.model.geo
    
    # default mesh size
    lc = 1.
    
    # Geometry
    # points
    p1 = factory.addPoint(0., 0., 0., lc)
    p2 = factory.addPoint(10., 0., 0., lc)
    p3 = factory.addPoint(0., 10., 0., lc)
    p4 = factory.addPoint(4., 0., 0., lc)
    p5 = factory.addPoint(0., 4., 0., lc)
    p6 = factory.addPoint(4., 4., 0., lc)
    angle = math.pi/4.
    p7 = factory.addPoint(10*math.cos(angle), 10*math.sin(angle),       0., lc)
    
    # lines
    l1 = factory.addLine(p5, p6)
    l2 = factory.addLine(p6, p4)
    l3 = factory.addLine(p4, p1)
    l4 = factory.addLine(p1, p5)
    l5 = factory.addLine(p4, p2)
    l6 = factory.addLine(p5, p3)
    l7 = factory.addLine(p6, p7)
    l8 = factory.addCircleArc(p2, p1, p7)
    l9 = factory.addCircleArc(p7, p1, p3)
    
    # curve loops
    cl1 = factory.addCurveLoop([l3, l4, l1, l2])
    cl2 = factory.addCurveLoop([l7, l9, -l6, l1])
    cl3 = factory.addCurveLoop([l5, l8, -l7, l2])
    
    # surfaces
    s1 = factory.addPlaneSurface([cl1])
    s2 = factory.addPlaneSurface([cl2])
    s3 = factory.addPlaneSurface([cl3])
    
    # extrusions
    dx = 5.
    num_els_z = 10
    factory.extrude([(2, s1), (2, s2), (2, s3)], 0., 0., dx,
                    numElements=[num_els_z], recombine=True)
    
    factory.synchronize()
    
    # Meshing
    meshFact = gmsh.model.mesh
    
    # transfinite curves
    n_nodes = 10
    # "Progression" 1 is default
    meshFact.setTransfiniteCurve(l1, numNodes=n_nodes)
    meshFact.setTransfiniteCurve(l2, numNodes=n_nodes)
    meshFact.setTransfiniteCurve(l3, numNodes=n_nodes)
    meshFact.setTransfiniteCurve(l4, numNodes=n_nodes)
    meshFact.setTransfiniteCurve(l5, numNodes=n_nodes)
    meshFact.setTransfiniteCurve(l6, numNodes=n_nodes)
    meshFact.setTransfiniteCurve(l7, numNodes=n_nodes)
    meshFact.setTransfiniteCurve(l8, numNodes=n_nodes)
    meshFact.setTransfiniteCurve(l9, numNodes=n_nodes)
    # transfinite surfaces
    meshFact.setTransfiniteSurface(s1)
    meshFact.setTransfiniteSurface(s2)
    meshFact.setTransfiniteSurface(s3)
    
    # mesh
    meshFact.generate(2)
    meshFact.recombine()
    meshFact.generate(3)
    
    gmsh.fltk.run()
    
    gmsh.finalize()


if __name__ == "__main__":
    main()
# Out:
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 10%] Meshing curve 2 (Line)
# Info    : [ 10%] Meshing curve 3 (Line)
# Info    : [ 20%] Meshing curve 4 (Line)
# Info    : [ 20%] Meshing curve 5 (Line)
# Info    : [ 30%] Meshing curve 6 (Line)
# Info    : [ 30%] Meshing curve 7 (Line)
# Info    : [ 30%] Meshing curve 8 (Circle)
# Info    : [ 40%] Meshing curve 9 (Circle)
# Info    : [ 40%] Meshing curve 17 (Extruded)
# Info    : [ 50%] Meshing curve 18 (Extruded)
# Info    : [ 50%] Meshing curve 19 (Extruded)
# Info    : [ 50%] Meshing curve 20 (Extruded)
# Info    : [ 60%] Meshing curve 22 (Extruded)
# Info    : [ 60%] Meshing curve 23 (Extruded)
# Info    : [ 70%] Meshing curve 27 (Extruded)
# Info    : [ 70%] Meshing curve 31 (Extruded)
# Info    : [ 70%] Meshing curve 39 (Extruded)
# Info    : [ 80%] Meshing curve 40 (Extruded)
# Info    : [ 80%] Meshing curve 41 (Extruded)
# Info    : [ 90%] Meshing curve 45 (Extruded)
# Info    : [ 90%] Meshing curve 49 (Extruded)
# Info    : [ 90%] Meshing curve 61 (Extruded)
# Info    : [100%] Meshing curve 62 (Extruded)
# Info    : [100%] Meshing curve 67 (Extruded)
# Info    : Done meshing 1D (Wall 0.00296843s, CPU 0.003462s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 1 (Transfinite)
# Info    : [ 10%] Meshing surface 2 (Transfinite)
# Info    : [ 20%] Meshing surface 3 (Transfinite)
# Info    : [ 30%] Meshing surface 24 (Extruded)
# Info    : [ 30%] Meshing surface 28 (Extruded)
# Info    : [ 40%] Meshing surface 32 (Extruded)
# Info    : [ 50%] Meshing surface 36 (Extruded)
# Info    : [ 50%] Meshing surface 37 (Extruded)
# Info    : [ 60%] Meshing surface 46 (Extruded)
# Info    : [ 70%] Meshing surface 50 (Extruded)
# Info    : [ 70%] Meshing surface 54 (Extruded)
# Info    : [ 80%] Meshing surface 59 (Extruded)
# Info    : [ 90%] Meshing surface 68 (Extruded)
# Info    : [ 90%] Meshing surface 72 (Extruded)
# Info    : [100%] Meshing surface 81 (Extruded)
# Info    : Done meshing 2D (Wall 0.00697822s, CPU 0.004062s)
# Info    : 1253 nodes 2028 elements
# Info    : Recombining 2D mesh...
# Info    : Blossom: 225 internal 34 closed
# Info    : Blossom recombination completed (Wall 0.00248375s, CPU 0.001141s): 81 quads, 0 triangles, 0 invalid quads, 0 quads with Q < 0.1, avg Q = 1, min Q = 1
# Info    : Blossom: 225 internal 34 closed
# Info    : Blossom recombination completed (Wall 0.000843432s, CPU 0.000818s): 81 quads, 0 triangles, 0 invalid quads, 0 quads with Q < 0.1, avg Q = 0.87506, min Q = 0.5
# Info    : Blossom: 225 internal 34 closed
# Info    : Blossom recombination completed (Wall 0.000883233s, CPU 0.000838s): 81 quads, 0 triangles, 0 invalid quads, 0 quads with Q < 0.1, avg Q = 0.875104, min Q = 0.5
# Info    : Blossom recombination completed (Wall 0.000480896s, CPU 0.000452s): 90 quads, 0 triangles, 0 invalid quads, 0 quads with Q < 0.1, avg Q = 1, min Q = 1
# Info    : Blossom recombination completed (Wall 0.000458641s, CPU 0.000416s): 90 quads, 0 triangles, 0 invalid quads, 0 quads with Q < 0.1, avg Q = 1, min Q = 1
# Info    : Blossom recombination completed (Wall 0.00044097s, CPU 0.000397s): 90 quads, 0 triangles, 0 invalid quads, 0 quads with Q < 0.1, avg Q = 1, min Q = 1
# Info    : Blossom recombination completed (Wall 0.000450222s, CPU 0.000417s): 90 quads, 0 triangles, 0 invalid quads, 0 quads with Q < 0.1, avg Q = 1, min Q = 1
# Info    : Blossom: 225 internal 34 closed
# Info    : Blossom recombination completed (Wall 0.000723948s, CPU 0.000658s): 81 quads, 0 triangles, 0 invalid quads, 0 quads with Q < 0.1, avg Q = 1, min Q = 1
# Info    : Blossom recombination completed (Wall 0.00037954s, CPU 0.000402s): 90 quads, 0 triangles, 0 invalid quads, 0 quads with Q < 0.1, avg Q = 1, min Q = 1
# Info    : Blossom recombination completed (Wall 0.0003437s, CPU 0.000361s): 90 quads, 0 triangles, 0 invalid quads, 0 quads with Q < 0.1, avg Q = 1, min Q = 1
# Info    : Blossom recombination completed (Wall 0.000443679s, CPU 0.0004s): 90 quads, 0 triangles, 0 invalid quads, 0 quads with Q < 0.1, avg Q = 1, min Q = 1
# Info    : Blossom: 225 internal 34 closed
# Info    : Blossom recombination completed (Wall 0.000844767s, CPU 0.00072s): 81 quads, 0 triangles, 0 invalid quads, 0 quads with Q < 0.1, avg Q = 0.87506, min Q = 0.5
# Info    : Blossom recombination completed (Wall 0.000509235s, CPU 0.000142s): 90 quads, 0 triangles, 0 invalid quads, 0 quads with Q < 0.1, avg Q = 1, min Q = 1
# Info    : Blossom recombination completed (Wall 0.000692442s, CPU 0.000756s): 90 quads, 0 triangles, 0 invalid quads, 0 quads with Q < 0.1, avg Q = 1, min Q = 1
# Info    : Blossom: 225 internal 34 closed
# Info    : Blossom recombination completed (Wall 0.000744661s, CPU 0.000709s): 81 quads, 0 triangles, 0 invalid quads, 0 quads with Q < 0.1, avg Q = 0.875104, min Q = 0.5
# Info    : Done recombining 2D mesh (Wall 0.0111285s, CPU 0.009011s)
# Info    : Meshing 3D...
# Info    : Meshing volume 3 (Extruded)
# Info    : Meshing volume 4 (Extruded)
# Info    : Meshing volume 5 (Extruded)
# Info    : Done meshing 3D (Wall 0.0106113s, CPU 0.009621s)
# Info    : Optimizing mesh...
# Info    : Done optimizing mesh (Wall 3.755e-05s, CPU 2.7e-05s)
# Info    : 2981 nodes 3972 elements
# Warning : Gmsh has aleady been initialized
# Error   : Can't open display:  (FLTK internal error)
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# /tmp/ipykernel_691/3321779478.py in ?()
#      79     gmsh.finalize()
#      80
#      81
#      82 if __name__ == "__main__":
# ---> 83     main()
#
# /tmp/ipykernel_691/3321779478.py in ?()
#      73     meshFact.generate(2)
#      74     meshFact.recombine()
#      75     meshFact.generate(3)
#      76
# ---> 77     gmsh.fltk.run()
#      78
#      79     gmsh.finalize()
#
# /usr/local/lib/gmsh.py in ?()
#   10249         ierr = c_int()
#   10250         lib.gmshFltkRun(
#   10251             byref(ierr))
#   10252         if ierr.value != 0:
# > 10253             raise Exception(logger.getLastError())
#
# Exception: Can't open display:  (FLTK internal error)
